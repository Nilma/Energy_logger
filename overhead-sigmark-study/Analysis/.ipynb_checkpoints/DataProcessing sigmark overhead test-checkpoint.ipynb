# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import integrate
import numpy as np
import matplotlib.pyplot as plt
import os
import re
import csv, json
from sklearn.metrics import root_mean_squared_error,mean_squared_error
import numpy as np

from statsmodels.stats.weightstats import ttost_ind
import statsmodels.formula.api as smf
import statsmodels.api as sm
# use the dedicated RMSE function (sklearn ≥1.4)
from sklearn.metrics import root_mean_squared_error
rmse = root_mean_squared_error([1,2,3], [1.1,1.9,3.2])
print(rmse)
import statsmodels
print(statsmodels.__version__)
# Out:
# 0.14142135623730964
# 0.14.2

# %%
# !pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in /opt/anaconda3/lib/python3.12/site-packages (0.14.2)
# Requirement already satisfied: numpy>=1.22.3 in /opt/anaconda3/lib/python3.12/site-packages (from statsmodels) (1.26.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /opt/anaconda3/lib/python3.12/site-packages (from statsmodels) (1.13.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /opt/anaconda3/lib/python3.12/site-packages (from statsmodels) (2.2.2)
# Requirement already satisfied: patsy>=0.5.6 in /opt/anaconda3/lib/python3.12/site-packages (from statsmodels) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in /opt/anaconda3/lib/python3.12/site-packages (from statsmodels) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2023.3)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.12/site-packages (from patsy>=0.5.6->statsmodels) (1.16.0)

# %%
import sys, inspect, sklearn, sklearn.metrics as M
print("Python:", sys.version)
print("scikit-learn:", sklearn.__version__)
print("Signature:", inspect.signature(M.mean_squared_error))
print("From module:", M.mean_squared_error.__module__)
print("Kernel executable:", sys.executable)
# Out:
# Python: 3.12.2 (v3.12.2:6abddd9f6a, Feb  6 2024, 17:02:06) [Clang 13.0.0 (clang-1300.0.29.30)]
# scikit-learn: 1.7.2
# Signature: (y_true, y_pred, *, sample_weight=None, multioutput='uniform_average')
# From module: sklearn.metrics._regression
# Kernel executable: /Users/nilmaabbas/Documents/GitHub/Energy_logger_CPU/.venv/bin/python

# %% [markdown]
# # Read me
#
# This script relies on the data being chunked by "DataChunking_sigmark_overheadtest.ipynb" and that we have obtained one csv file for each of the tests. If in doubt, check your "ChunkedData" folder.
#
# The following imports the chunked data and provides us with two dataframes:
# - dfs which holds the energy data for all the test
# - df_powers holds all the power measurements for all the tests
#
# After the import, the data is ready for your

# %%
input_directory = '../ChunkedData'
output_directory = '../Results/'

# %%
# this part reads the chunked data files related to the

# %%
# ls ../ChunkedData

# %%
# pd.read_csv('../ChunkedData_Stress/sigmark_0_siglent.1762858356709.CH1.csv',nrows=1,header=0)

# we want to  keep id2, exp_duration, count as  test, exp_duration, no_of_messages

# %%
#import all the CSV files

# (a) Read from row 3 and on into df and calculate energy consumption
# (b) Read the first two lines with meta data, add the calculated energy consumption and concat to the existing
ID = 0
list_of_metadataframes = []
list_of_dataframes = []
for input_file in os.listdir(input_directory):
    file_path = input_directory+'/'
    file_name = os.path.basename(input_file)
    if file_name.endswith('.csv'):
        print(input_file)
        df = pd.read_csv(file_path+file_name,skiprows=2, names=['timestamp','channel','action','payload'])
        # print(file_path+file_name,df['timestamp'].dtypes)
        df['time'] = (df['timestamp']-df['timestamp'].min()) / 1000
        df['ID'] = ID
        x = df['time']
        y = df['payload']
        y_int = integrate.cumulative_trapezoid(y, x, initial=0)
        #plt.plot(x, y_int)
        #plt.plot(x,y)
        #plt.savefig('')
        #plt.show()
        energy = y_int[-1]
        df_main = pd.read_csv(file_path+file_name,nrows=1,header=0,usecols = [1,4,5],names=['test','exp_duration','no_of_messages'])
        df_main['duration']=df['time'].max() # in seconds
        df_main['energy']=energy  # in joules
        df_main['power_avg']= energy/df_main['duration'] # in Watt
        df_main['ID'] = ID
        # print(df_main)
        df['test']=df_main['test'][0]
        df['no_of_messages']=df_main['no_of_messages'][0]
        df['ID'] = ID
        list_of_metadataframes.append(df_main)
        list_of_dataframes.append(df)
        ID = ID + 1

#dfs = pd.concat(list_of_metadataframes)
#df_power = pd.concat(list_of_dataframes)
# Out:
# sigmark_10_1764594415302_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_2_1764590716437_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764599881769_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_20_1764592646945_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_20_1764593772502_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_2_1764592404726_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_20_1764597149171_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764598193471_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764585249860_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_5_1764602936987_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_4_1764587822391_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_2_1764584526130_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764590796774_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_10_1764593852531_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_5_1764591118777_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_4_1764587259645_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_5_1764592807065_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_2_1764595781376_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764596987265_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764603177746_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_5_1764600685892_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_5_1764589430489_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_10_1764589913160_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764593691245_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_10_1764597791984_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764602614974_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_4_1764599077752_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_4_1764591198927_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764585731982_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764589189121_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_20_1764594335273_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_5_1764597872075_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764601007286_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_4_1764592887213_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764602695616_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764597067912_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764600926653_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764584043697_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_10_1764596666415_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_5_1764595058172_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_20_1764587019376_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_20_1764589270373_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_2_1764596344156_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_4_1764590636165_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764592485058_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764599319005_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764588545741_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_5_1764587179494_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_10_1764591038689_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_2_1764600846317_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_20_1764586456617_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_2_1764602534638_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_2_1764596906929_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_2_1764601971863_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764602052196_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_10_1764596103644_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_10_1764602294124_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_10_1764600605804_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_5_1764587742240_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_20_1764599963011_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764599801131_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764592002934_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764590877411_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764585812613_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_2_1764591279199_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_4_1764586134125_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_2_1764591841968_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_20_1764599400260_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_5_1764597309291_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_2_1764586777158_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_4_1764603017140_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764591922299_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_20_1764598274712_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_2_1764586214398_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_10_1764586536648_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764600444528_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_20_1764602214094_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764600363889_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_5_1764595620947_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_5_1764591681546_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_10_1764590475927_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_20_1764593209723_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_5_1764584928471_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_20_1764585331107_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_5_1764586053974_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_5_1764602374213_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_5_1764598997600_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_2_1764587339918_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_5_1764598434831_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_2_1764585088891_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_10_1764585973884_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764590234004_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_20_1764601088546_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764594736156_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764588626379_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_5_1764585491226_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_5_1764584365708_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_5_1764600123131_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_10_1764601168575_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_10_1764588224899_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_4_1764586696885_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_10_1764602856896_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_20_1764594898053_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_2_1764592967489_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764593610600_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_4_1764588385140_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764594254024_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_4_1764585008620_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_20_1764595460827_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_4_1764600766044_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_20_1764584768353_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_5_1764601248666_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_10_1764594978083_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764601570059_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_2_1764600283552_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_4_1764597389442_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764602132839_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_20_1764592084187_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_5_1764596746504_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_20_1764583642816_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_4_1764594575544_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_4_1764583883092_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764594173387_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_5_1764594495392_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764603258390_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_10_1764585411137_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_10_1764598354741_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_2_1764598032501_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_20_1764591521427_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_5_1764588867729_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764586294736_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_10_1764595540856_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_4_1764585571375_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764587500882_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_20_1764601651319_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764597630703_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764596424489_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_4_1764588947879_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764595298935_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764595379574_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764587420250_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764589108486_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_2_1764589028151_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_20_1764596586387_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_4_1764601891589_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_2_1764601409090_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764587982996_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_5_1764589993250_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_2_1764585651647_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764586375373_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_4_1764596826655_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764584687103_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_10_1764584848382_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_20_1764590958660_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764586857490_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764596505126_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764585169224_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_2_1764603097414_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_10_1764593289752_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764601489423_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_10_1764587662151_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_4_1764591761696_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_5_1764586616737_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_20_1764590395898_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_4_1764598514984_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_2_1764587902665_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764586938132_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_10_1764600043040_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_2_1764583963363_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_5_1764596183732_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764590314643_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_20_1764584205588_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_20_1764585893855_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_20_1764589833130_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_5_1764583802936_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_10_1764588787642_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_5_1764590556016_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_20_1764588144870_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_4_1764595138324_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_4_1764590073401_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764598756226_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_2_1764595218599_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_2_1764589590915_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_20_1764602776867_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_10_1764589350401_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764584124335_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_4_1764601328817_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764595942354_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_4_1764592324455_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_5_1764588304988_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_4_1764594012778_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_2_1764599158029_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_2_1764590153671_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764592565690_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_20_1764598837480_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_20_1764588707614_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_10_1764599480288_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_5_1764601811438_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_5_1764599560377_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_5_1764593932627_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_10_1764583722847_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_20_1764587582122_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764584606465_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764598675592_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_20_1764600525775_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_5_1764593369841_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_4_1764600203280_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764597550059_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_2_1764597469721_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_5_1764592244306_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_10_1764597229200_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_10_1764601731349_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_4_1764589510640_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_2_1764599720799_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_4_1764596263882_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764593128471_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764589751882_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764593047828_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_10_1764592164216_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_2_1764594093052_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764588063629_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_4_1764595701099_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_10_1764598917509_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_4_1764602454364_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_4_1764597952227_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_2_1764593530262_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_4_1764593449991_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_20_1764596023614_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_2_1764594655820_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764595861712_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764591440172_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764594816801_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_4_1764584445857_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_2_1764598595257_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_4_1764599640527_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764591359534_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_10_1764592726974_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_10_1764587099405_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_10_1764591601457_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_2_1764588465413_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764599238368_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_20_1764597711956_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_10_1764584285617_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764598112838_siglent.1764662359266.CH1_homemade_script.csv
# sigmark_1_1764589671247_siglent.1764662359266.CH1_homemade_script.csv

# %%
dfs =pd.concat(list_of_metadataframes)

# %%
dfs = dfs.sort_values(by='test')
dfs = dfs.reset_index(drop=True)

# %%
dfs
# Out:
#      test  exp_duration  no_of_messages  duration      energy  power_avg   ID
# 0       1         81235              80    81.230  195.746275   2.409778  122
# 1       1         81226              80    81.209  196.174000   2.415668  140
# 2       1         80015               0    80.008  189.231600   2.365158  139
# 3       1         81239              80    81.222  195.708150   2.409546  138
# 4       1         81247              80    81.241  195.612600   2.407806  136
# ..    ...           ...             ...       ...         ...        ...  ...
# 240    20         80075               4    80.069  189.330550   2.364592  128
# 241    20         80074               4    80.071  189.835700   2.370842  134
# 242    20         80076               4    80.056  189.180025   2.363096  173
# 243    20         80077               4    80.067  188.934225   2.359702   59
# 244    20         80075               4    80.073  189.466525   2.366172  201
#
# [245 rows x 7 columns]

# %%
df_powers = pd.concat(list_of_dataframes)

# %%
df_powers = df_powers.reset_index(drop=True)

# %%
df_powers
# Out:
#              timestamp channel action  payload    time   ID  test  \
# 0        1764594495393     CH1  POWER     2.35   0.000    0    10
# 1        1764594495397     CH1  POWER     2.35   0.004    0    10
# 2        1764594495403     CH1  POWER     2.35   0.010    0    10
# 3        1764594495407     CH1  POWER     2.35   0.014    0    10
# 4        1764594495415     CH1  POWER     2.35   0.022    0    10
# ...                ...     ...    ...      ...     ...  ...   ...
# 3467291  1764589833087     CH1  POWER     2.35  81.202  244     1
# 3467292  1764589833095     CH1  POWER     2.35  81.210  244     1
# 3467293  1764589833101     CH1  POWER     2.35  81.216  244     1
# 3467294  1764589833106     CH1  POWER     2.35  81.221  244     1
# 3467295  1764589833112     CH1  POWER     2.35  81.227  244     1
#
#          no_of_messages
# 0                     8
# 1                     8
# 2                     8
# 3                     8
# 4                     8
# ...                 ...
# 3467291              80
# 3467292              80
# 3467293              80
# 3467294              80
# 3467295              80
#
# [3467296 rows x 8 columns]

# %% [markdown]
# # Nilma and Jespers Evaluation
#
# The above imports the chunked data and provides us with two dataframes:
# - dfs which holds the energy data for all the test
# - df_powers holds all the power measurements for all the tests
#
# 1. Ultimately, we want to find out how much energy the raspberry pi is using per tick.
# 2. We need to verify whether we can trust the data.

# %%
# first, we want to know how much energy is used for each number_of_messages

sns.scatterplot(data= dfs, x='no_of_messages',y='energy')
# Out:
# <Axes: xlabel='no_of_messages', ylabel='energy'>

# %%
dfs['energy_normalized_80s'] = dfs['energy']/dfs['duration']

# %%
dfs.quantile(0.25)
# Out:
# test                  1.00000
# exp_duration      80076.00000
# no_of_messages        4.00000
# duration             80.07300
# energy              189.26290
# power_avg             2.36363
# ID                   61.00000
# Name: 0.25, dtype: float64

# %%
def remove_outliers_iqr(data, k=1.5, column="energy"):
    q1 = data[column].quantile(0.25)
    q3 = data[column].quantile(0.75)
    iqr = q3 - q1

    lower = q1 - k * iqr
    upper = q3 + k * iqr

    return data[(data[column] >= lower) & (data[column] <= upper)]

dfs_filtered = (
    dfs
    .groupby('no_of_messages', group_keys=False)
    .apply(remove_outliers_iqr)
)
# Out:
# /var/folders/v5/7jxn000s4bj5xzgtytbkndv80000gn/T/ipykernel_48377/1182068376.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(remove_outliers_iqr)

# %%
sns.scatterplot(data= dfs_filtered, x='no_of_messages',y='energy')
# Out:
# <Axes: xlabel='no_of_messages', ylabel='energy'>

# %% [markdown]
# ### The Best-fit Global Model
#
# $\text{energy} = a \cdot \text{number of messages} + b$
#
# - $a$: baseline slope (effect of sending a message).
# - $b$: global intercept (baseline energy when number of messages = 0).
#
# R-squared (R²) is defined as a number that tells you how well the independent variable(s) in a statistical model explains the variation in the dependent variable. It ranges from 0 to 1, where 1 indicates a perfect fit of the model to the data.
#
# While R² is often between 0 and 1, it can be negative when the model performs worse than predicting the mean of the data.

# %%
model = smf.ols("energy ~ no_of_messages", data=dfs_filtered).fit()
print(model.summary())

# Scatterplot of error vs duration
plt.figure(figsize=(8,6))
sns.scatterplot(x="no_of_messages", y="energy", data=dfs_filtered, alpha=0.6, edgecolor=None)

# Regression line (from statsmodels fit)
x_vals = np.linspace(dfs_filtered["no_of_messages"].min(), dfs_filtered["no_of_messages"].max(), 200)
y_vals = model.params['Intercept'] + model.params['no_of_messages']*x_vals  # from the regression model

r2_text = f"Fitted line (R² = {model.rsquared:.3f})"
plt.plot(x_vals, y_vals, color="blue", linewidth=2, linestyle='--',label=r2_text)

plt.title("Energy per Number of messages")
plt.ylabel('Energy (J)')
plt.xlabel('Number of Messages')
plt.legend()
plt.grid(alpha=0.3)
plt.savefig(output_directory+'energy_pr_no_of_message.png')
plt.show()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 energy   R-squared:                       0.979
# Model:                            OLS   Adj. R-squared:                  0.979
# Method:                 Least Squares   F-statistic:                 1.102e+04
# Date:                Fri, 30 Jan 2026   Prob (F-statistic):          3.40e-198
# Time:                        09:53:00   Log-Likelihood:                -80.676
# No. Observations:                 235   AIC:                             165.4
# Df Residuals:                     233   BIC:                             172.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept        188.8422      0.031   6156.842      0.000     188.782     188.903
# no_of_messages     0.0913      0.001    104.993      0.000       0.090       0.093
# ==============================================================================
# Omnibus:                        6.956   Durbin-Watson:                   1.932
# Prob(Omnibus):                  0.031   Jarque-Bera (JB):                8.147
# Skew:                           0.258   Prob(JB):                       0.0170
# Kurtosis:                       3.752   Cond. No.                         48.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
sns.boxplot(data= dfs_filtered, x='no_of_messages',y='duration')
plt.title("Total Execution Time per Number of messages")
plt.ylabel('Time (s)')
plt.xlabel('Number of Messages')
plt.legend()
plt.grid(alpha=0.3)
plt.savefig(output_directory+'eduration_pr_no_of_message_boxplot.png')
plt.show()
# Out:
# /var/folders/v5/7jxn000s4bj5xzgtytbkndv80000gn/T/ipykernel_48377/2430837351.py:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
model = smf.ols("duration ~ no_of_messages", data=dfs_filtered).fit()
print(model.summary())

# Scatterplot of error vs duration
plt.figure(figsize=(8,6))
sns.scatterplot(x="no_of_messages", y="duration", data=dfs_filtered, alpha=0.6, edgecolor=None)

# Regression line (from statsmodels fit)
x_vals = np.linspace(dfs_filtered["no_of_messages"].min(), dfs_filtered["no_of_messages"].max(), 200)
y_vals = model.params['Intercept'] + model.params['no_of_messages']*x_vals  # from the regression model

r2_text = f"Fitted line (R² = {model.rsquared:.3f})"
plt.plot(x_vals, y_vals, color="blue", linewidth=2, linestyle='--',label=r2_text)

plt.title("Time per Number of messages")
plt.ylabel('Total Execution Time (s)')
plt.xlabel('Number of Messages')
plt.legend()
plt.grid(alpha=0.3)
plt.savefig(output_directory+'duration_pr_no_of_message.png')
plt.show()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               duration   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.067e+06
# Date:                Thu, 29 Jan 2026   Prob (F-statistic):               0.00
# Time:                        15:31:06   Log-Likelihood:                 877.00
# No. Observations:                 235   AIC:                            -1750.
# Df Residuals:                     233   BIC:                            -1743.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept         80.0078      0.001   1.54e+05      0.000      80.007      80.009
# no_of_messages     0.0153   1.48e-05   1032.991      0.000       0.015       0.015
# ==============================================================================
# Omnibus:                       67.347   Durbin-Watson:                   2.034
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              150.403
# Skew:                          -1.357   Prob(JB):                     2.19e-33
# Kurtosis:                       5.827   Cond. No.                         48.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
